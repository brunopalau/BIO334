# %%
import cobra
sys.path.append("/Library/Python/3.8/site-packages")

from cobra import Model, Reaction, Metabolite
from cobra.flux_analysis import single_reaction_deletion

# %%
model = cobra.io.read_sbml_model('iJO1366.xml')

# %%
# exercise 4.1
print(f"nr metabolites: {len(model.metabolites)}, nr genes: {len(model.genes)}, nr reactions {len(model.reactions)}")
# Out:
# nr metabolites: 1805, nr genes: 1367, nr reactions 2583

# %%
# optimize objective function biomass
model.objective.expression
fba_solution = model.optimize()

# %%
# find active reactions
active_reactions = fba_solution.fluxes[round(fba_solution.fluxes,4) != 0]

# %%
# find active external reactions
for reaction in model.exchanges:
    if round(reaction.flux,4) != 0:
        print(reaction.id)
# Out:
# EX_ca2_e
# EX_cl_e
# EX_co2_e
# EX_cu2_e
# EX_fe2_e
# EX_glc__D_e
# EX_h_e
# EX_h2o_e
# EX_k_e
# EX_mg2_e
# EX_mn2_e
# EX_mobd_e
# EX_nh4_e
# EX_ni2_e
# EX_o2_e
# EX_pi_e
# EX_so4_e
# EX_zn2_e

# %%
# find active external reactions
for active_reaction in active_reactions.index:
    reaction = model.reactions.get_by_id(active_reaction)
    if reaction.compartments == {"e"}:
        print(reaction.id)
# Out:
# EX_ca2_e
# EX_cl_e
# EX_co2_e
# EX_cu2_e
# EX_fe2_e
# EX_glc__D_e
# EX_h_e
# EX_h2o_e
# EX_k_e
# EX_mg2_e
# EX_mn2_e
# EX_mobd_e
# EX_nh4_e
# EX_ni2_e
# EX_o2_e
# EX_pi_e
# EX_so4_e
# EX_zn2_e

# %%
# take a look at all exchange reactions
for x in model.exchanges:
    print(f"{x.name}  {x.id} ....")
# Out:
# (R)-Propane-1,2-diol exchange  EX_12ppd__R_e ....
# (S)-Propane-1,2-diol exchange  EX_12ppd__S_e ....
# 1,4-alpha-D-glucan exchange  EX_14glucan_e ....
# 1,5-Diaminopentane exchange  EX_15dap_e ....
# 2',3'-Cyclic AMP exchange  EX_23camp_e ....
# 2',3'-Cyclic CMP exchange  EX_23ccmp_e ....
# 2',3'-Cyclic GMP exchange  EX_23cgmp_e ....
# 2',3'-Cyclic UMP exchange  EX_23cump_e ....
# 2,3-diaminopropionate exchange  EX_23dappa_e ....
# Meso-2,6-Diaminoheptanedioate exchange  EX_26dap__M_e ....
# 2-Dehydro-3-deoxy-D-gluconate exchange  EX_2ddglcn_e ....
# 3,4-Dihydroxyphenylacetaldehyde exchange  EX_34dhpac_e ....
# 3'-AMP exchange  EX_3amp_e ....
# 3'-cmp exchange  EX_3cmp_e ....
# 3'-GMP exchange  EX_3gmp_e ....
# 3-hydroxycinnamic acid exchange  EX_3hcinnm_e ....
# 3-Hydroxypropanoate exchange  EX_3hpp_e ....
# 3-(3-hydroxy-phenyl)propionate exchange  EX_3hpppn_e ....
# 3'-UMP exchange  EX_3ump_e ....
# 4-Aminobutanoate exchange  EX_4abut_e ....
# 4-Hydroxyphenylacetaldehyde exchange  EX_4hoxpacd_e ....
# 5-Dehydro-D-gluconate exchange  EX_5dglcn_e ....
# 5-Methylthio-D-ribose exchange  EX_5mtr_e ....
# L-alanine-D-glutamate exchange  EX_LalaDglu_e ....
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate exchange  EX_LalaDgluMdap_e ....
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine exchange  EX_LalaDgluMdapDala_e ....
# L-alanine-L-glutamate exchange  EX_LalaLglu_e ....
# Acetate exchange  EX_ac_e ....
# Acetoacetate exchange  EX_acac_e ....
# Acetaldehyde exchange  EX_acald_e ....
# N-Acetyl-D-galactosamine exchange  EX_acgal_e ....
# N-Acetyl-D-galactosamine 1-phosphate exchange  EX_acgal1p_e ....
# N-Acetyl-D-glucosamine exchange  EX_acgam_e ....
# N-Acetyl-D-glucosamine 1-phosphate exchange  EX_acgam1p_e ....
# N-Acetyl-D-mannosamine exchange  EX_acmana_e ....
# N-Acetylmuramate exchange  EX_acmum_e ....
# N-Acetylneuraminate exchange  EX_acnam_e ....
# 4-Amino-4-deoxy-L-arabinose modified core oligosaccharide lipid A exchange  EX_acolipa_e ....
# O-Acetyl-L-serine exchange  EX_acser_e ....
# Adenine exchange  EX_ade_e ....
# Adenosine exchange  EX_adn_e ....
# Adenosylcobalamin exchange  EX_adocbl_e ....
# Silver exchange  EX_ag_e ....
# Agmatine exchange  EX_agm_e ....
# 2-Oxoglutarate exchange  EX_akg_e ....
# Beta-Alanine exchange  EX_ala_B_e ....
# D-Alanine exchange  EX_ala__D_e ....
# L-Alanine exchange  EX_ala__L_e ....
# D-Alanyl-D-alanine exchange  EX_alaala_e ....
# D-Allose exchange  EX_all__D_e ....
# Allantoin exchange  EX_alltn_e ....
# AMP exchange  EX_amp_e ....
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid exchange  EX_anhgm_e ....
# L-Arabinose exchange  EX_arab__L_e ....
# Arbutin exchange  EX_arbt_e ....
# Aerobactin minus Fe3 exchange  EX_arbtn_e ....
# Aerobactin exchange  EX_arbtn_fe3_e ....
# L-Arginine exchange  EX_arg__L_e ....
# L-Ascorbate exchange  EX_ascb__L_e ....
# L-Asparagine exchange  EX_asn__L_e ....
# Arsenite exchange  EX_aso3_e ....
# L-Aspartate exchange  EX_asp__L_e ....
# Biotin exchange  EX_btn_e ....
# Butyrate (n-C4:0) exchange  EX_but_e ....
# Butanesulfonate exchange  EX_butso3_e ....
# Calcium exchange  EX_ca2_e ....
# Cobinamide exchange  EX_cbi_e ....
# Cob(I)alamin exchange  EX_cbl1_e ....
# Cadmium exchange  EX_cd2_e ....
# Cys-Gly exchange  EX_cgly_e ....
# Choline exchange  EX_chol_e ....
# Chitobiose exchange  EX_chtbs_e ....
# Citrate exchange  EX_cit_e ....
# Chloride exchange  EX_cl_e ....
# Chloramphenicol exchange  EX_cm_e ....
# CMP exchange  EX_cmp_e ....
# CO2 exchange  EX_co2_e ....
# Co2+ exchange  EX_cobalt2_e ....
# Core oligosaccharide lipid A exchange  EX_colipa_e ....
# Core oligosaccharide lipid A diphosphate exchange  EX_colipap_e ....
# Coprogen exchange  EX_cpgn_e ....
# Coprogen unloaded (no Fe(III)) exchange  EX_cpgn_un_e ....
# L-Carnitine exchange  EX_crn_e ....
# D-carnitine exchange  EX_crn__D_e ....
# Cytosine exchange  EX_csn_e ....
# Cu+ exchange  EX_cu_e ....
# Cu2+ exchange  EX_cu2_e ....
# Hydrogen cyanide exchange  EX_cyan_e ....
# Cyanate exchange  EX_cynt_e ....
# D-Cysteine exchange  EX_cys__D_e ....
# L-Cysteine exchange  EX_cys__L_e ....
# Cytidine exchange  EX_cytd_e ....
# Deoxyadenosine exchange  EX_dad_2_e ....
# DAMP exchange  EX_damp_e ....
# Decanoate (n-C10:0) exchange  EX_dca_e ....
# DCMP exchange  EX_dcmp_e ....
# Deoxycytidine exchange  EX_dcyt_e ....
# Dodecanoate (n-C12:0) exchange  EX_ddca_e ....
# DGMP exchange  EX_dgmp_e ....
# Deoxyguanosine exchange  EX_dgsn_e ....
# Dihydroxyacetone exchange  EX_dha_e ....
# DIMP exchange  EX_dimp_e ....
# Deoxyinosine exchange  EX_din_e ....
# Dimethyl sulfide exchange  EX_dms_e ....
# Dimethyl sulfoxide exchange  EX_dmso_e ....
# Dopamine exchange  EX_dopa_e ....
# Doxorubicin exchange  EX_doxrbcn_e ....
# DTMP exchange  EX_dtmp_e ....
# DUMP exchange  EX_dump_e ....
# Deoxyuridine exchange  EX_duri_e ....
# (enterobacterial common antigen)x4 core oligosaccharide lipid A exchange  EX_eca4colipa_e ....
# Phosphoethanolamine KDO(2)-lipid (A) exchange  EX_enlipa_e ....
# Enterochelin exchange  EX_enter_e ....
# Ethanolamine exchange  EX_etha_e ....
# Ethanesulfonate exchange  EX_ethso3_e ....
# Ethanol exchange  EX_etoh_e ....
# D-fructose 6-phosphate exchange  EX_f6p_e ....
# Formaldehyde exchange  EX_fald_e ....
# Fe2+ exchange  EX_fe2_e ....
# Fe3+ exchange  EX_fe3_e ....
# Fe(III)dicitrate exchange  EX_fe3dcit_e ....
# Ferric 2,3-dihydroxybenzoylserine exchange  EX_fe3dhbzs_e ....
# Fe(III)hydroxamate exchange  EX_fe3hox_e ....
# Fe(III)hydoxamate, unloaded exchange  EX_fe3hox_un_e ....
# Ferrichrome exchange  EX_fecrm_e ....
# Ferrichrome minus Fe(III) exchange  EX_fecrm_un_e ....
# Fe-enterobactin exchange  EX_feenter_e ....
# Ferroxamine exchange  EX_feoxam_e ....
# Ferroxamine minus Fe(3) exchange  EX_feoxam_un_e ....
# Formate exchange  EX_for_e ....
# D-Fructose exchange  EX_fru_e ....
# Fructoselysine exchange  EX_frulys_e ....
# D-Fructuronate exchange  EX_fruur_e ....
# L-Fucose exchange  EX_fuc__L_e ....
# Fumarate exchange  EX_fum_e ....
# Fusidic acid exchange  EX_fusa_e ....
# D-Glucose 1-phosphate exchange  EX_g1p_e ....
# Sn-Glycero-3-phosphocholine exchange  EX_g3pc_e ....
# Sn-Glycero-3-phosphoethanolamine exchange  EX_g3pe_e ....
# Glycerophosphoglycerol exchange  EX_g3pg_e ....
# Sn-Glycero-3-phospho-1-inositol exchange  EX_g3pi_e ....
# Glycerophosphoserine exchange  EX_g3ps_e ....
# D-Glucose 6-phosphate exchange  EX_g6p_e ....
# D-Galactose exchange  EX_gal_e ....
# Beta D-Galactose exchange  EX_gal_bD_e ....
# Alpha-D-Galactose 1-phosphate exchange  EX_gal1p_e ....
# D-Galactarate exchange  EX_galct__D_e ....
# D-Galactonate exchange  EX_galctn__D_e ....
# L-Galactonate exchange  EX_galctn__L_e ....
# Galactitol exchange  EX_galt_e ....
# D-Galacturonate exchange  EX_galur_e ....
# D-Glucosamine exchange  EX_gam_e ....
# D-Glucosamine 6-phosphate exchange  EX_gam6p_e ....
# Gamma-butyrobetaine exchange  EX_gbbtn_e ....
# GDP exchange  EX_gdp_e ....
# D-Glucose exchange  EX_glc__D_e ....
# D-Gluconate exchange  EX_glcn_e ....
# D-Glucarate exchange  EX_glcr_e ....
# D-Glucuronate exchange  EX_glcur_e ....
# D-Glucuronate 1-phosphate exchange  EX_glcur1p_e ....
# L-Glutamine exchange  EX_gln__L_e ....
# L-Glutamate exchange  EX_glu__L_e ....
# Glycine exchange  EX_gly_e ....
# D-Glyceraldehyde exchange  EX_glyald_e ....
# Glycine betaine exchange  EX_glyb_e ....
# Glycerol exchange  EX_glyc_e ....
# (R)-Glycerate exchange  EX_glyc__R_e ....
# Glycerol 2-phosphate exchange  EX_glyc2p_e ....
# Glycerol 3-phosphate exchange  EX_glyc3p_e ....
# Glycolate exchange  EX_glyclt_e ....
# GMP exchange  EX_gmp_e ....
# Guanosine exchange  EX_gsn_e ....
# Oxidized glutathione exchange  EX_gthox_e ....
# Reduced glutathione exchange  EX_gthrd_e ....
# GTP exchange  EX_gtp_e ....
# Guanine exchange  EX_gua_e ....
# H+ exchange  EX_h_e ....
# H2 exchange  EX_h2_e ....
# H2O exchange  EX_h2o_e ....
# Hydrogen peroxide exchange  EX_h2o2_e ....
# Hydrogen sulfide exchange  EX_h2s_e ....
# Hepta-acylated core oligosaccharide lipid A (E. coli) exchange  EX_hacolipa_e ....
# Hepta-acylated KDO(2)-lipid (A) exchange  EX_halipa_e ....
# Hexadecanoate (n-C16:0) exchange  EX_hdca_e ....
# Hexadecenoate (n-C16:1) exchange  EX_hdcea_e ....
# Hg2+ exchange  EX_hg2_e ....
# L-Histidine exchange  EX_his__L_e ....
# L-Homoserine exchange  EX_hom__L_e ....
# Hexanoate (n-C6:0) exchange  EX_hxa_e ....
# Hypoxanthine exchange  EX_hxan_e ....
# L-Idonate exchange  EX_idon__L_e ....
# L-Isoleucine exchange  EX_ile__L_e ....
# IMP exchange  EX_imp_e ....
# Indole exchange  EX_indole_e ....
# Myo-Inositol exchange  EX_inost_e ....
# Inosine exchange  EX_ins_e ....
# Isethionic acid exchange  EX_isetac_e ....
# K+ exchange  EX_k_e ....
# KDO(2)-lipid IV(A) exchange  EX_kdo2lipid4_e ....
# D-lactate exchange  EX_lac__D_e ....
# L-Lactate exchange  EX_lac__L_e ....
# Lactose exchange  EX_lcts_e ....
# L-Leucine exchange  EX_leu__L_e ....
# KDO(2)-lipid (A) exchange  EX_lipa_e ....
# Cold adapted KDO(2)-lipid (A) exchange  EX_lipa_cold_e ....
# Lipoate exchange  EX_lipoate_e ....
# L-Lysine exchange  EX_lys__L_e ....
# L-Lyxose exchange  EX_lyx__L_e ....
# D-Malate exchange  EX_mal__D_e ....
# L-Malate exchange  EX_mal__L_e ....
# Maltose exchange  EX_malt_e ....
# Maltohexaose exchange  EX_malthx_e ....
# Maltopentaose exchange  EX_maltpt_e ....
# Maltotriose exchange  EX_malttr_e ....
# Maltotetraose exchange  EX_maltttr_e ....
# D-Mannose exchange  EX_man_e ....
# D-Mannose 6-phosphate exchange  EX_man6p_e ....
# 2(alpha-D-Mannosyl)-D-glycerate exchange  EX_manglyc_e ....
# Melibiose exchange  EX_melib_e ....
# Methanol exchange  EX_meoh_e ....
# D-Methionine exchange  EX_met__D_e ....
# L-Methionine exchange  EX_met__L_e ....
# L-methionine-R-sulfoxide exchange  EX_metsox_R__L_e ....
# L-Methionine S-oxide exchange  EX_metsox_S__L_e ....
# Mg exchange  EX_mg2_e ....
# Minocycline exchange  EX_mincyc_e ....
# Myo-Inositol hexakisphosphate exchange  EX_minohp_e ....
# S-Methyl-L-methionine exchange  EX_mmet_e ....
# Mn2+ exchange  EX_mn2_e ....
# D-Mannitol exchange  EX_mnl_e ....
# Molybdate exchange  EX_mobd_e ....
# Methanesulfonate exchange  EX_mso3_e ....
# Nitrous oxide exchange  EX_n2o_e ....
# Sodium exchange  EX_na1_e ....
# Nicotinate exchange  EX_nac_e ....
# Ammonia exchange  EX_nh4_e ....
# Ni2+ exchange  EX_ni2_e ....
# NMN exchange  EX_nmn_e ....
# Nitric oxide exchange  EX_no_e ....
# Nitrite exchange  EX_no2_e ....
# Nitrate exchange  EX_no3_e ....
# Novobiocin exchange  EX_novbcn_e ....
# (O16 antigen)x4 core oligosaccharide lipid A exchange  EX_o16a4colipa_e ....
# O2 exchange  EX_o2_e ....
# Superoxide anion exchange  EX_o2s_e ....
# Octadecanoate (n-C18:0) exchange  EX_ocdca_e ....
# Octadecenoate (n-C18:1) exchange  EX_ocdcea_e ....
# Octanoate (n-C8:0) exchange  EX_octa_e ....
# Ornithine exchange  EX_orn_e ....
# Orotate exchange  EX_orot_e ....
# Phenylacetaldehyde exchange  EX_pacald_e ....
# Phenethylamine exchange  EX_peamn_e ....
# L-Phenylalanine exchange  EX_phe__L_e ....
# Protoheme exchange  EX_pheme_e ....
# Phosphate exchange  EX_pi_e ....
# (R)-Pantothenate exchange  EX_pnto__R_e ....
# Propionate exchange  EX_ppa_e ....
# Propanal exchange  EX_ppal_e ....
# Phenylpropanoate exchange  EX_pppn_e ....
# Phosphonate exchange  EX_ppt_e ....
# L-Proline exchange  EX_pro__L_e ....
# L-Prolinylglycine exchange  EX_progly_e ....
# Psicoselysine exchange  EX_psclys_e ....
# O-Phospho-L-serine exchange  EX_pser__L_e ....
# Putrescine exchange  EX_ptrc_e ....
# Pyridoxamine exchange  EX_pydam_e ....
# Pyridoxal exchange  EX_pydx_e ....
# Pyridoxine exchange  EX_pydxn_e ....
# Pyruvate exchange  EX_pyr_e ....
# Quinate exchange  EX_quin_e ....
# Alpha-D-Ribose 5-phosphate exchange  EX_r5p_e ....
# Rifampin exchange  EX_rfamp_e ....
# D-Ribose exchange  EX_rib__D_e ....
# L-Rhamnose exchange  EX_rmn_e ....
# D-Sorbitol exchange  EX_sbt__D_e ....
# Selenate exchange  EX_sel_e ....
# D-Serine exchange  EX_ser__D_e ....
# L-Serine exchange  EX_ser__L_e ....
# Shikimate exchange  EX_skm_e ....
# Selenite exchange  EX_slnt_e ....
# Sulfur dioxide exchange  EX_so2_e ....
# Sulfite exchange  EX_so3_e ....
# Sulfate exchange  EX_so4_e ....
# Spermidine exchange  EX_spmd_e ....
# Succinate exchange  EX_succ_e ....
# Sucrose exchange  EX_sucr_e ....
# Sulfoacetate exchange  EX_sulfac_e ....
# D-tartrate exchange  EX_tartr__D_e ....
# L-tartrate exchange  EX_tartr__L_e ....
# Taurine exchange  EX_taur_e ....
# Thiocyanate exchange  EX_tcynt_e ....
# Thiamin exchange  EX_thm_e ....
# L-Threonine exchange  EX_thr__L_e ....
# L-Threonine O-3-phosphate exchange  EX_thrp_e ....
# Thymine exchange  EX_thym_e ....
# Thymidine exchange  EX_thymd_e ....
# Trimethylamine exchange  EX_tma_e ....
# Trimethylamine N-oxide exchange  EX_tmao_e ....
# Trehalose exchange  EX_tre_e ....
# L-Tryptophan exchange  EX_trp__L_e ....
# Thiosulfate exchange  EX_tsul_e ....
# Tetradecanoate (n-C14:0) exchange  EX_ttdca_e ....
# Tetradecenoate (n-C14:1) exchange  EX_ttdcea_e ....
# Tetracycline exchange  EX_ttrcyc_e ....
# Tungstate exchange  EX_tungs_e ....
# Tyramine exchange  EX_tym_e ....
# L-Tyrosine exchange  EX_tyr__L_e ....
# Phosphotyrosine exchange  EX_tyrp_e ....
# UDP-N-acetyl-D-glucosamine exchange  EX_uacgam_e ....
# UDP-N-acetyl-D-galactosamine exchange  EX_udpacgal_e ....
# UDPglucose exchange  EX_udpg_e ....
# UDPgalactose exchange  EX_udpgal_e ....
# UDP-D-glucuronate exchange  EX_udpglcur_e ....
# UMP exchange  EX_ump_e ....
# Uracil exchange  EX_ura_e ....
# Urea exchange  EX_urea_e ....
# Uridine exchange  EX_uri_e ....
# L-Valine exchange  EX_val__L_e ....
# Xanthine exchange  EX_xan_e ....
# Xanthosine 5'-phosphate exchange  EX_xmp_e ....
# Xanthosine exchange  EX_xtsn_e ....
# D-Xylose exchange  EX_xyl__D_e ....
# L-Xylulose exchange  EX_xylu__L_e ....
# Zinc exchange  EX_zn2_e ....

# %%
# exercise 4.2
# find all essential reactions, in glucose minimal environment
glucose_reaction = ["EX_g1p_e","EX_g6p_e"]
# set glucose minimal environment
for reaction in model.exchanges:
    for metabolites in reaction.metabolites:
        if "C" in metabolites.elements:
            if reaction.id in glucose_reaction:
                model.reactions.get_by_id(reaction.id).lower_bound = -1000
            else:
                model.reactions.get_by_id(reaction.id).lower_bound = 0
            break
model.medium #active exchange reactions?
# Out:
# {'EX_ca2_e': 1000.0,
#  'EX_cl_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_g1p_e': 1000,
#  'EX_g6p_e': 1000,
#  'EX_h_e': 1000.0,
#  'EX_h2o_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_mobd_e': 1000.0,
#  'EX_na1_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_ni2_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_sel_e': 1000.0,
#  'EX_slnt_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_tungs_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
# find eessentials
fba_sol = model.optimize()
deletion_solution = single_reaction_deletion(model)

# %%
# get rid of 0 growth aswell as infeasible
deletion_solution.growth = round(deletion_solution.growth,3)
essential = deletion_solution[(deletion_solution.growth!=0) ^ (deletion_solution.status!="infeasible")]
essential
# Out:
#             ids  growth   status
# 2      {MG2tex}     0.0  optimal
# 5       {OMCDC}     0.0  optimal
# 39       {CYSS}     0.0  optimal
# 44     {AICART}     0.0  optimal
# 56    {PSSA161}    -0.0  optimal
# ...         ...     ...      ...
# 2553      {ANS}    -0.0  optimal
# 2556    {ARGSL}    -0.0  optimal
# 2563   {G1PACT}    -0.0  optimal
# 2573   {PAPPT3}     0.0  optimal
# 2576       {CS}     0.0  optimal
#
# [286 rows x 3 columns]

# %%
# compute fraction of reactions that are essential
len(essential)/len(model.reactions) # 11 percent are essential
# Out:
# 0.11072396438250097

# %%
# exericse 4.3
# set acetat minimal environment
glucose_reaction = ["EX_ac_e"]
# set glucose minimal environment
for reaction in model.exchanges:
    for metabolites in reaction.metabolites:
        if "C" in metabolites.elements:
            if reaction.id in glucose_reaction:
                model.reactions.get_by_id(reaction.id).lower_bound = -1000
            else:
                model.reactions.get_by_id(reaction.id).lower_bound = 0
            break
model.medium #active exchange reactions?
# Out:
# {'EX_ac_e': 1000,
#  'EX_ca2_e': 1000.0,
#  'EX_cl_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_h_e': 1000.0,
#  'EX_h2o_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_mobd_e': 1000.0,
#  'EX_na1_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_ni2_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_sel_e': 1000.0,
#  'EX_slnt_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_tungs_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
fba_solution = model.optimize()
acetat_deletion = single_reaction_deletion(model)
acetat_deletion
# Out:
#                   ids        growth   status
# 0     {EX_LalaDglu_e}  1.024217e+01  optimal
# 1          {CLt3_2pp}  3.109086e-16  optimal
# 2      {LPLIPAL2G180}  1.024217e+01  optimal
# 3           {URACPAH}  1.024217e+01  optimal
# 4           {EAR140x}  1.024217e+01  optimal
# ...               ...           ...      ...
# 2578          {DHQTi} -1.688263e-14  optimal
# 2579        {EAR121x}  1.024217e+01  optimal
# 2580       {CYSabcpp}  1.024217e+01  optimal
# 2581         {DHNPTE}  1.024217e+01  optimal
# 2582       {EX_fe3_e}  1.024217e+01  optimal
#
# [2583 rows x 3 columns]

# %%
acetat_essential = acetat_deletion[(round(acetat_deletion.growth,3) != 0) ^(acetat_deletion.status != "infeasible")]

len(acetat_essential)/len(model.reactions) # 11.4 percent are essential
# Out:
# 0.11498257839721254

# %%
# exercise 4.4
acetat_essentail_unique = []
for ids in acetat_essential.ids:
    if ids not in essential.ids.values:
        acetat_essentail_unique.append(reaction)
print(acetat_essentail_unique)
# Out:
# [<Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>, <Reaction EX_zn2_e at 0x2843c94e0>]

# %%
# exercise 4.5
# load in subsystem info file
dic_sub = {}
with open("iJO1366_reactionInfo.csv") as file:
    for line in file:
        line = line.strip()
        info = line.split(",")
        reaction = info[0]
        subsystem = info[6]
        dic_sub[reaction] = subsystem

# %%
sub_count = {}
ids = essential.ids.values
for id_ in ids[1:]:
    id_ = id_.pop()
    subsystem = dic_sub[id_]
    if subsystem not in sub_count:
        sub_count[subsystem] = 0
    sub_count[subsystem] += 1
sub_count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [175], in <cell line: 3>()
#       3 for id_ in ids[1:]:
#       4     id_ = id_.pop()
# ----> 5     subsystem = dic_sub[id_]
#       6     if subsystem not in sub_count:
#       7         sub_count[subsystem] = 0
#
# KeyError: 'EX_meoh_e'

# %%
sub_count
# Out:
# {'Valine  Leucine  and Isoleucine Metabolism': 1,
#  'Cysteine Metabolism': 2,
#  'Purine and Pyrimidine Biosynthesis': 4,
#  'Glycerophospholipid Metabolism': 2,
#  'Histidine Metabolism': 2,
#  'Cofactor and Prosthetic Group Biosynthesis': 10,
#  'Nucleotide Salvage Pathway': 3,
#  'Cell Envelope Biosynthesis': 4,
#  'Lipopolysaccharide Biosynthesis / Recycling': 2,
#  'Transport  Outer Membrane Porin': 1,
#  'Threonine and Lysine Metabolism': 1,
#  'Arginine and Proline Metabolism': 1,
#  'Alternate Carbon Metabolism': 1,
#  'Inorganic Ion Transport and Metabolism': 2,
#  'Folate Metabolism': 1}

# %%
# exercise 4.6
