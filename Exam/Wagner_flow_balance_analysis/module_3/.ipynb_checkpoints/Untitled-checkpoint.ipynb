# %%
import sys

sys.path.append("/Library/Python/3.8/site-packages")

import cobra

from cobra import Model, Reaction, Metabolite
# Out:
# /Library/Python/3.8/site-packages/cobra/core/dictlist.py:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_length is 0:

# %%
# exercise 5
model_sakai = cobra.io.read_sbml_model('iEco1345_Sakai.xml')
model_mg = cobra.io.read_sbml_model('iEco1339_MG1655.xml')

list_model = [model_sakai, model_mg]

# %%
for ex in model_sakai.exchanges:
    print(ex)
# Out:
# EX_m_4hba_c_Cytosol_boundary: m_4hba_c_Cytosol_boundary <=>
# EX_m_5drib_c_Cytosol_boundary: m_5drib_c_Cytosol_boundary <=>
# EX_m_aacald_c_Cytosol_boundary: m_aacald_c_Cytosol_boundary <=>
# EX_m_hmfurn_c_Cytosol_boundary: m_hmfurn_c_Cytosol_boundary <=>
# EX_m_oxam_c_Cytosol_boundary: m_oxam_c_Cytosol_boundary <=>
# EX_m_12ppd_r_e_Extracellular_boundary: m_12ppd_r_e_Extracellular_boundary <=>
# EX_m_12ppd_s_e_Extracellular_boundary: m_12ppd_s_e_Extracellular_boundary <=>
# EX_m_14glucan_e_Extracellular_boundary: m_14glucan_e_Extracellular_boundary <=>
# EX_m_15dap_e_Extracellular_boundary: m_15dap_e_Extracellular_boundary <=>
# EX_m_23camp_e_Extracellular_boundary: m_23camp_e_Extracellular_boundary <=>
# EX_m_23ccmp_e_Extracellular_boundary: m_23ccmp_e_Extracellular_boundary <=>
# EX_m_23cgmp_e_Extracellular_boundary: m_23cgmp_e_Extracellular_boundary <=>
# EX_m_23cump_e_Extracellular_boundary: m_23cump_e_Extracellular_boundary <=>
# ...

# %%
# set glucose minimal environment
for model in list_model:
